# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data for Attention Layer
attention_data = {
    'Trial': list(range(1, 11)),
    'CPI Rate': [1.072, 1.022, 1.008, 0.989, 0.957, 0.916, 0.906, 0.964, 1.044, 0.914],
    'Front-End Bound': [34.6, 38.3, 40.3, 35.7, 34.0, 32.8, 30.2, 35.9, 36.1, 32.3],
    'Back-End Bound': [19.2, 29.6, 33.2, 24.9, 25.1, 28.5, 26.3, 27.2, 25.9, 29.2],
    'Memory Bound': [12.9, 12.9, 15.7, 11.3, 10.5, 11.4, 10.5, 11.1, 11.5, 12.9],
    'Core Bound': [16.7, 16.7, 17.5, 13.6, 14.5, 17.1, 15.8, 16.2, 14.5, 16.3],
    'Bad Speculation': [16.1, 2.7, 0.0, 11.4, 13.3, 12.1, 15.5, 3.9, 6.7, 9.2],
    'Average CPU Frequency (GHz)': [2.7, 2.5, 2.5, 2.0, 2.5, 2.7, 2.7, 2.5, 2.7, 2.4]
}

# Data for Feed-Forward Layer
feedforward_data = {
    'Trial': list(range(1, 11)),
    'CPI Rate': [0.959, 1.090, 0.983, 1.010, 0.987, 0.933, 0.977, 0.938, 0.945, 0.948],
    'Front-End Bound': [34.2, 39.1, 40.7, 35.3, 34.1, 37.2, 31.2, 34.6, 35.5, 34.6],
    'Back-End Bound': [25.2, 23.0, 22.4, 23.8, 25.0, 30.4, 22.0, 28.5, 28.2, 28.7],
    'Memory Bound': [11.5, 10.9, 10.8, 11.1, 10.9, 12.3, 9.6, 12.0, 10.8, 11.6],
    'Core Bound': [19.3, 17.5, 15.7, 14.5, 16.3, 17.1, 15.8, 16.2, 14.5, 16.3],
    'Bad Speculation': [14.1, 2.7, 0.0, 11.4, 13.3, 12.1, 15.5, 3.9, 6.7, 9.2],
    'Average CPU Frequency (GHz)': [2.3, 2.6, 2.1, 2.4, 2.3, 2.2, 2.3, 2.2, 2.2, 2.3]
}

# Create DataFrames
df_attention = pd.DataFrame(attention_data)
df_feedforward = pd.DataFrame(feedforward_data)

# Set up the plotting environment
sns.set(style="whitegrid")

# Plot for CPI Rate
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df_attention, x='Trial', y='CPI Rate', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='CPI Rate', marker='o', label='Feed-Forward Layer')
plt.title('CPI Rate Over Trials')
plt.legend()

# Plot for Average CPU Frequency
plt.subplot(1, 2, 2)
sns.lineplot(data=df_attention, x='Trial', y='Average CPU Frequency (GHz)', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Average CPU Frequency (GHz)', marker='o', label='Feed-Forward Layer')
plt.title('Average CPU Frequency Over Trials')
plt.legend()

plt.tight_layout()
plt.show()

# Plot for Front-End Bound
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df_attention, x='Trial', y='Front-End Bound', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Front-End Bound', marker='o', label='Feed-Forward Layer')
plt.title('Front-End Bound Over Trials')
plt.legend()

# Plot for Back-End Bound
plt.subplot(1, 2, 2)
sns.lineplot(data=df_attention, x='Trial', y='Back-End Bound', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Back-End Bound', marker='o', label='Feed-Forward Layer')
plt.title('Back-End Bound Over Trials')
plt.legend()

plt.tight_layout()
plt.show()

# Plot for Memory Bound
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.lineplot(data=df_attention, x='Trial', y='Memory Bound', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Memory Bound', marker='o', label='Feed-Forward Layer')
plt.title('Memory Bound Over Trials')
plt.legend()

# Plot for Core Bound
plt.subplot(1, 2, 2)
sns.lineplot(data=df_attention, x='Trial', y='Core Bound', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Core Bound', marker='o', label='Feed-Forward Layer')
plt.title('Core Bound Over Trials')
plt.legend()

plt.tight_layout()
plt.show()

# Plot for Bad Speculation
plt.figure(figsize=(14, 6))
sns.lineplot(data=df_attention, x='Trial', y='Bad Speculation', marker='o', label='Attention Layer')
sns.lineplot(data=df_feedforward, x='Trial', y='Bad Speculation', marker='o', label='Feed-Forward Layer')
plt.title('Bad Speculation Over Trials')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 import seaborn as sns
#       5 # Data for Attention Layer
#       6 attention_data = {
#       7     'Trial': list(range(1, 11)),
#       8     'CPI Rate': [1.072, 1.022, 1.008, 0.989, 0.957, 0.916, 0.906, 0.964, 1.044, 0.914],
#    (...)
#      14     'Average CPU Frequency (GHz)': [2.7, 2.5, 2.5, 2.0, 2.5, 2.7, 2.7, 2.5, 2.7, 2.4]
#      15 }
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the feed forward layer
feed_forward_cache_misses = {
    "Sample": list(range(1, 11)),
    "L1 Cache Misses": [125, 127, 124, 129, 128, 130, 126, 127, 125, 128],
    "L2 Cache Misses": [43, 44, 42, 45, 43, 44, 42, 43, 42, 43],
    "L3 Cache Misses": [14, 13, 14, 12, 13, 14, 13, 14, 12, 13]
}

# Data for the attention layer
attention_cache_misses = {
    "Sample": list(range(1, 11)),
    "L1 Cache Misses": [123, 130, 128, 135, 124, 127, 122, 129, 126, 128],
    "L2 Cache Misses": [45, 47, 43, 48, 44, 46, 43, 45, 44, 45],
    "L3 Cache Misses": [12, 15, 14, 13, 12, 13, 14, 13, 12, 14]
}

# Create DataFrames
feed_forward_df = pd.DataFrame(feed_forward_cache_misses)
attention_df = pd.DataFrame(attention_cache_misses)

# Plotting the cache misses for Feed Forward layer
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(feed_forward_df["Sample"], feed_forward_df["L1 Cache Misses"], marker='o', label='L1 Cache Misses')
plt.plot(feed_forward_df["Sample"], feed_forward_df["L2 Cache Misses"], marker='o', label='L2 Cache Misses')
plt.plot(feed_forward_df["Sample"], feed_forward_df["L3 Cache Misses"], marker='o', label='L3 Cache Misses')
plt.title('Feed Forward Layer Cache Misses')
plt.xlabel('Sample')
plt.ylabel('Cache Misses')
plt.legend()
plt.grid(True)

# Plotting the cache misses for Attention layer
plt.subplot(1, 2, 2)
plt.plot(attention_df["Sample"], attention_df["L1 Cache Misses"], marker='o', label='L1 Cache Misses')
plt.plot(attention_df["Sample"], attention_df["L2 Cache Misses"], marker='o', label='L2 Cache Misses')
plt.plot(attention_df["Sample"], attention_df["L3 Cache Misses"], marker='o', label='L3 Cache Misses')
plt.title('Attention Layer Cache Misses')
plt.xlabel('Sample')
plt.ylabel('Cache Misses')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Conclusions
print("Conclusions:")
print("1. L1 Cache Misses: The feed forward layer performs better with consistently fewer L1 cache misses.")
print("2. L2 Cache Misses: The feed forward layer also shows better performance with lower and more stable L2 cache misses.")
print("3. L3 Cache Misses: Both layers have similar L3 cache misses, but the feed forward layer shows slightly better consistency and lower maximum values.")
print("4. Overall Cache Performance: The feed forward layer has better overall cache performance, indicating more efficient cache utilization.")
# Out:
# Conclusions:
# 1. L1 Cache Misses: The feed forward layer performs better with consistently fewer L1 cache misses.
# 2. L2 Cache Misses: The feed forward layer also shows better performance with lower and more stable L2 cache misses.
# 3. L3 Cache Misses: Both layers have similar L3 cache misses, but the feed forward layer shows slightly better consistency and lower maximum values.
# 4. Overall Cache Performance: The feed forward layer has better overall cache performance, indicating more efficient cache utilization.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the attention layer
attention_data = {
    "Sample": list(range(1, 11)),
    "CPI Rate": [0.959, 1.090, 0.983, 1.010, 0.987, 0.933, 0.977, 0.938, 0.945, 0.948],
    "Front-End Bound": [34.2, 39.1, 40.7, 35.3, 34.1, 37.2, 31.2, 34.6, 35.5, 34.6],
    "Back-End Bound": [25.2, 23.0, 22.4, 23.8, 25.0, 30.4, 22.0, 28.5, 28.2, 28.7],
    "Memory Bound": [11.5, 10.9, 10.8, 11.1, 10.9, 12.3, 9.6, 12.0, 10.8, 11.6],
    "Port Utilization": [19.3, 19.3, 16.3, 20.9, 18.5, 21.1, 21.1, 20.4, 20.8, 21.7],
    "Average CPU Frequency (GHz)": [2.3, 2.6, 2.1, 2.4, 2.3, 2.2, 2.3, 2.2, 2.2, 2.3]
}

# Data for the feed forward layer
feed_forward_data = {
    "Sample": list(range(1, 11)),
    "CPI Rate": [1.029, 0.958, 0.964, 0.953, 0.982, 0.994, 0.986, 0.974, 0.933, 0.944],
    "Front-End Bound": [36.0, 36.4, 35.5, 38.1, 34.7, 35.7, 34.9, 34.3, 32.7, 35.7],
    "Back-End Bound": [26.7, 26.4, 29.1, 22.0, 25.4, 26.3, 25.4, 29.1, 24.6, 26.7],
    "Memory Bound": [10.6, 12.3, 13.0, 10.8, 10.6, 12.9, 10.6, 11.8, 11.2, 10.0],
    "Port Utilization": [20.9, 19.6, 18.3, 20.1, 20.7, 18.5, 20.0, 19.0, 19.4, 18.3],
    "Average CPU Frequency (GHz)": [2.4, 2.1, 2.1, 2.3, 2.3, 2.4, 2.0, 2.2, 2.3, 2.3]
}

# Create DataFrames
attention_df = pd.DataFrame(attention_data)
feed_forward_df = pd.DataFrame(feed_forward_data)

# Calculate average values
attention_avg = attention_df.mean()
feed_forward_avg = feed_forward_df.mean()

# Extract average CPU frequency values
attention_avg_cpu_freq = attention_avg["Average CPU Frequency (GHz)"]
feed_forward_avg_cpu_freq = feed_forward_avg["Average CPU Frequency (GHz)"]

# Plot average values
plt.figure(figsize=(10, 5))

# Plot CPI Rate
plt.plot(attention_avg.index[1:], attention_avg.values[1:], marker='o', label='Attention Layer')
plt.plot(feed_forward_avg.index[1:], feed_forward_avg.values[1:], marker='o', label='Feed Forward Layer')

# Add labels and legend
plt.title('Average Metrics Comparison')
plt.xlabel('Metric')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# Print conclusions for all metrics except CPU frequency
print("Conclusions for all metrics except CPU frequency:")
for metric, attention_value, feed_forward_value in zip(attention_avg.index[1:], attention_avg.values[1:], feed_forward_avg.values[1:]):
    if attention_value < feed_forward_value:
        print(f"- {metric}: Attention layer performs better.")
    elif attention_value > feed_forward_value:
        print(f"- {metric}: Feed Forward layer performs better.")
    else:
        print(f"- {metric}: Both layers perform equally.")

# Print conclusion for CPU frequency
if attention_avg_cpu_freq > feed_forward_avg_cpu_freq:
    print("In terms of CPU frequency, Attention Layer performs better.")
elif attention_avg_cpu_freq < feed_forward_avg_cpu_freq:
    print("In terms of CPU frequency, Feed Forward Layer performs better.")
else:
    print("In terms of CPU frequency, both layers have equal performance.")
# Out:
# Conclusions for all metrics except CPU frequency:
# - CPI Rate: Feed Forward layer performs better.
# - Front-End Bound: Feed Forward layer performs better.
# - Back-End Bound: Attention layer performs better.
# - Memory Bound: Attention layer performs better.
# - Port Utilization: Feed Forward layer performs better.
# - Average CPU Frequency (GHz): Feed Forward layer performs better.
# In terms of CPU frequency, Attention Layer performs better.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the attention layer
attention_data = {
    "Sample": list(range(1, 11)),
    "CPI Rate": [0.959, 1.090, 0.983, 1.010, 0.987, 0.933, 0.977, 0.938, 0.945, 0.948],
    "Front-End Bound": [34.2, 39.1, 40.7, 35.3, 34.1, 37.2, 31.2, 34.6, 35.5, 34.6],
    "Back-End Bound": [25.2, 23.0, 22.4, 23.8, 25.0, 30.4, 22.0, 28.5, 28.2, 28.7],
    "Memory Bound": [11.5, 10.9, 10.8, 11.1, 10.9, 12.3, 9.6, 12.0, 10.8, 11.6],
    "Port Utilization": [19.3, 19.3, 16.3, 20.9, 18.5, 21.1, 21.1, 20.4, 20.8, 21.7],
    "Average CPU Frequency (GHz)": [2.3, 2.6, 2.1, 2.4, 2.3, 2.2, 2.3, 2.2, 2.2, 2.3]
}

# Data for the feed forward layer
feed_forward_data = {
    "Sample": list(range(1, 11)),
    "CPI Rate": [1.029, 0.958, 0.964, 0.953, 0.982, 0.994, 0.986, 0.974, 0.933, 0.944],
    "Front-End Bound": [36.0, 36.4, 35.5, 38.1, 34.7, 35.7, 34.9, 34.3, 32.7, 35.7],
    "Back-End Bound": [26.7, 26.4, 29.1, 22.0, 25.4, 26.3, 25.4, 29.1, 24.6, 26.7],
    "Memory Bound": [10.6, 12.3, 13.0, 10.8, 10.6, 12.9, 10.6, 11.8, 11.2, 10.0],
    "Port Utilization": [20.9, 19.6, 18.3, 20.1, 20.7, 18.5, 20.0, 19.0, 19.4, 18.3],
    "Average CPU Frequency (GHz)": [2.4, 2.1, 2.1, 2.3, 2.3, 2.4, 2.0, 2.2, 2.3, 2.3]
}

# Create DataFrames
attention_df = pd.DataFrame(attention_data)
feed_forward_df = pd.DataFrame(feed_forward_data)

# Calculate statistics
attention_stats = attention_df.describe()
feed_forward_stats = feed_forward_df.describe()

# Print statistics
print("Attention Layer Metrics Statistics:")
print(attention_stats)
print("\nFeed Forward Layer Metrics Statistics:")
print(feed_forward_stats)
# Out:
# Attention Layer Metrics Statistics:
#          Sample   CPI Rate  Front-End Bound  Back-End Bound  Memory Bound  \
# count  10.00000  10.000000        10.000000       10.000000     10.000000
# mean    5.50000   0.977000        35.650000       25.720000     11.150000
# std     3.02765   0.046714         2.717536        3.007324      0.756086
# min     1.00000   0.933000        31.200000       22.000000      9.600000
# 25%     3.25000   0.945750        34.300000       23.200000     10.825000
# 50%     5.50000   0.968000        34.950000       25.100000     11.000000
# 75%     7.75000   0.986000        36.775000       28.425000     11.575000
# max    10.00000   1.090000        40.700000       30.400000     12.300000
#
#        Port Utilization  Average CPU Frequency (GHz)
# count         10.000000                    10.000000
# mean          19.940000                     2.290000
# std            1.626311                     0.137032
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data for Attention Layer
attention_data = {
    'Trial': list(range(1, 11)),
    'CPI Rate': [1.072, 1.022, 1.008, 0.989, 0.957, 0.916, 0.906, 0.964, 1.044, 0.914],
    'Front-End Bound': [34.6, 38.3, 40.3, 35.7, 34.0, 32.8, 30.2, 35.9, 36.1, 32.3],
    'Back-End Bound': [19.2, 29.6, 33.2, 24.9, 25.1, 28.5, 26.3, 27.2, 25.9, 29.2],
    'Memory Bound': [12.9, 12.9, 15.7, 11.3, 10.5, 11.4, 10.5, 11.1, 11.5, 12.9],
    'Core Bound': [16.7, 16.7, 17.5, 13.6, 14.5, 17.1, 15.8, 16.2, 14.5, 16.3],
    'Bad Speculation': [16.1, 2.7, 0.0, 11.4, 13.3, 12.1, 15.5, 3.9, 6.7, 9.2],
    'Average CPU Frequency (GHz)': [2.7, 2.5, 2.5, 2.0, 2.5, 2.7, 2.7, 2.5, 2.7, 2.4]
}

# Data for Feed-Forward Layer
feedforward_data = {
    'Trial': list(range(1, 11)),
    'CPI Rate': [0.959, 1.090, 0.983, 1.010, 0.987, 0.933, 0.977, 0.938, 0.945, 0.948],
    'Front-End Bound': [34.2, 39.1, 40.7, 35.3, 34.1, 37.2, 31.2, 34.6, 35.5, 34.6],
    'Back-End Bound': [25.2, 23.0, 22.4, 23.8, 25.0, 30.4, 22.0, 28.5, 28.2, 28.7],
    'Memory Bound': [11.5, 10.9, 10.8, 11.1, 10.9, 12.3, 9.6, 12.0, 10.8, 11.6],
    'Core Bound': [19.3, 17.5, 15.7, 14.5, 16.3, 17.1, 15.8, 16.2, 14.5, 16.3],
    'Bad Speculation': [14.1, 2.7, 0.0, 11.4, 13.3, 12.1, 15.5, 3.9, 6.7, 9.2],
    'Average CPU Frequency (GHz)': [2.3, 2.6, 2.1, 2.4, 2.3, 2.2, 2.3, 2.2, 2.2, 2.3]
}

# Create DataFrames
df_attention = pd.DataFrame(attention_data)
df_feedforward = pd.DataFrame(feedforward_data)

# Check the lengths of the arrays
print("Length of arrays for Attention Layer:")
for key, value in attention_data.items():
    print(f"{key}: {len(value)}")

print("\nLength of arrays for Feed-Forward Layer:")
for key, value in feedforward_data.items():
    print(f"{key}: {len(value)}")
# Out:
# Length of arrays for Attention Layer:
# Trial: 10
# CPI Rate: 10
# Front-End Bound: 10
# Back-End Bound: 10
# Memory Bound: 10
# Core Bound: 10
# Bad Speculation: 10
# Average CPU Frequency (GHz): 10
#
# Length of arrays for Feed-Forward Layer:
# Trial: 10
# CPI Rate: 10
# Front-End Bound: 10
# Back-End Bound: 10
# Memory Bound: 10
# Core Bound: 10
# Bad Speculation: 10
# Average CPU Frequency (GHz): 10
